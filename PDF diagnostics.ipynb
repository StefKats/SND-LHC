# %%
import numpy as np
from rootpyPickler import Unpickler
import shipLHC_conf as sndDet_conf
import SndlhcGeo
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
import time
# Out:
# Welcome to JupyROOT 6.26/10

# %% [markdown]
# ### Plotting PDFs for fixed SciFi depths and a set of energies

# %%
_, ax = plt.subplots(nrows=1, ncols=1, figsize=(6,4), dpi=150)
for energy in [100,300,500,750,1000,1500]:
    PDF = np.loadtxt("/eos/home-i02/s/skatsaro/PGsim/depth_291/pions_{}/PDF/PDF_x_1.txt".format(energy))
    PDF_bins = plt.hist(np.linspace(-50,0,100),bins=np.linspace(-50,0,101),weights=PDF,histtype="step",
                        label=[str(energy)+" GeV"])

plt.xlabel("x [cm]")
plt.ylabel("PDF")
plt.title("Station1_x")
plt.legend(title="Energies")

# plt.savefig("station1_x_energies.png")
plt.show()

# %%
_, ax = plt.subplots(nrows=1, ncols=1, figsize=(6,4), dpi=150)
for energy in [100,300,500,750,1000,1500]:
    PDF = np.loadtxt("/eos/home-i02/s/skatsaro/PGsim/depth_291/pions_{}/PDF/PDF_y_1.txt".format(energy))
    PDF_bins = plt.hist(np.linspace(10,60,100),bins=np.linspace(10,60,101),weights=PDF,histtype="step",
                        label=[str(energy)+" GeV"])

plt.xlabel("y [cm]")
plt.ylabel("PDF")
plt.title("Station1_y")
plt.legend(title="Energies")

# plt.savefig("station1_y_energies.png")
plt.show()

# %%
_, ax = plt.subplots(nrows=1, ncols=1, figsize=(6,4), dpi=150)
for energy in [100,300,500,750,1000,1500]:
    PDF = np.loadtxt("/eos/home-i02/s/skatsaro/PGsim/depth_291/pions_{}/PDF/PDF_x_2.txt".format(energy))
    PDF_bins = plt.hist(np.linspace(-50,0,100),bins=np.linspace(-50,0,101),weights=PDF,histtype="step",
                        label=[str(energy)+" GeV"])

plt.xlabel("x [cm]")
plt.ylabel("PDF")
plt.title("Station2_x")
plt.legend(title="Energies")

# plt.savefig("station2_x_energies.png")
plt.show()

# %%
_, ax = plt.subplots(nrows=1, ncols=1, figsize=(6,4), dpi=150)
for energy in [100,300,500,750,1000,1500]:
    PDF = np.loadtxt("/eos/home-i02/s/skatsaro/PGsim/depth_291/pions_{}/PDF/PDF_y_2.txt".format(energy))
    PDF_bins = plt.hist(np.linspace(10,60,100),bins=np.linspace(10,60,101),weights=PDF,histtype="step",
                        label=[str(energy)+" GeV"])

plt.xlabel("y [cm]")
plt.ylabel("PDF")
plt.title("Station2_y")
plt.legend(title="Energies")

# plt.savefig("station2_y_energies.png")
plt.show()

# %% [markdown]
# ### Plotting PDFs for fixed SciFi depths and a set of shower initiation depths

# %%
_, ax = plt.subplots(nrows=1, ncols=1, figsize=(6,4), dpi=150)
for depth in [291,295,304,308]:
    PDF = np.loadtxt("/eos/home-i02/s/skatsaro/PGsim/depth_{}/pions_300/PDF/PDF_x_1.txt".format(depth))
    PDF_bins = plt.hist(np.linspace(-50,0,100),bins=np.linspace(-50,0,101),weights=PDF,histtype="step",
                        label=[str(depth)+" cm"])

plt.xlabel("x [cm]")
plt.ylabel("PDF")
plt.title("Station1_x")
plt.legend(title="Z position")

# plt.savefig("station1_x_depths.png")
plt.show()

# %%
_, ax = plt.subplots(nrows=1, ncols=1, figsize=(6,4), dpi=150)
for depth in [291,295,304,308]:
    PDF = np.loadtxt("/eos/home-i02/s/skatsaro/PGsim/depth_{}/pions_300/PDF/PDF_y_1.txt".format(depth))
    PDF_bins = plt.hist(np.linspace(10,60,100),bins=np.linspace(10,60,101),weights=PDF,histtype="step",
                        label=[str(depth)+" cm"])

plt.xlabel("y [cm]")
plt.ylabel("PDF")
plt.title("Station1_y")
plt.legend(title="Z position")

# plt.savefig("station1_y_depths.png")
plt.show()

# %%
_, ax = plt.subplots(nrows=1, ncols=1, figsize=(6,4), dpi=150)
for depth in [291,295,304,308]:
    PDF = np.loadtxt("/eos/home-i02/s/skatsaro/PGsim/depth_{}/pions_300/PDF/PDF_x_2.txt".format(depth))
    PDF_bins = plt.hist(np.linspace(-50,0,100),bins=np.linspace(-50,0,101),weights=PDF,histtype="step",
                        label=[str(depth)+" cm"])

plt.xlabel("x [cm]")
plt.ylabel("PDF")
plt.title("Station2_x")
plt.legend(title="Z position")

# plt.savefig("station2_x_depths.png")
plt.show()

# %%
_, ax = plt.subplots(nrows=1, ncols=1, figsize=(6,4), dpi=150)
for depth in [291,295,304,308]:
    PDF = np.loadtxt("/eos/home-i02/s/skatsaro/PGsim/depth_{}/pions_300/PDF/PDF_y_2.txt".format(depth))
    PDF_bins = plt.hist(np.linspace(10,60,100),bins=np.linspace(10,60,101),weights=PDF,histtype="step",
                        label=[str(depth)+" cm"])

plt.xlabel("y [cm]")
plt.ylabel("PDF")
plt.title("Station2_y")
plt.legend(title="Z position")

# plt.savefig("station2_y_depths.png")
plt.show()
